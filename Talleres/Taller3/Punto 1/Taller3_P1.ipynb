# %% [markdown]
# # Taller 3.  Tecnicas para la mejora del aprendizaje y del desempeño de las Redes Neuronales
# Nombres: Manuel Sanchez y Allan Ramirez

# %% [markdown]
# ### Codigo utilizado en el Taller #1

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.datasets import mnist
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import layers, models, optimizers

(train_images , train_labels) , (test_images , test_labels) = mnist.load_data()


train_images = train_images.reshape((60000, 28 * 28) )
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28) )
test_images = test_images.astype("float32") / 255

model = keras.Sequential([
    layers.Dense(512, activation ="sigmoid") ,
    layers.Dense(10, activation ="softmax")
])

model.compile(optimizer="SGD",
loss ="SparseCategoricalCrossentropy",
metrics =["accuracy"])

model.fit(train_images, train_labels, epochs=5)

test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5858 - loss: 1.7018
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8474 - loss: 0.6822
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8734 - loss: 0.5027
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8841 - loss: 0.4318
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8920 - loss: 0.3939
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8844 - loss: 0.4119

# %% [markdown]
# ## Parte I (60 ptos)
# 1. Utilice su codigo de red neuronal para el problema de reconocimiento de digitos MNIST
# del Taller 1 para estudiar como varia el desempeño de la red (en terminos generales) en
# funcion del numero de capas ocultas. Utilice las mismas funciones de activacion para no
# aumentar el riesgo de sesgos en su analisis. Describa sus observaciones.
#
# El codigo inicial contempla una red que tiene para este caso un modelo secuencial con dos capas densas (Dense):
#
# *   La primera capa tiene 512 neuronas con la función de activación sigmoide
# *   La segunda capa tiene 10 neuronas con la función de activación softmax
#
# Para realizar comparaciones solo iremos aumentando la capas de densas con funcion de activacion sigmoide, entonces trabajaremos otros 4 modelos en donde cada ira aumentando de a una capa oculta y reviseramos sus resultados para determinar como cambia el desempeño de la red.

# %%
# Creación de listas para guardar accuracy y modelos
modelos = [str(a) for a in range(1, 5)]
accuracy = [test_acc]

# Modelo 1.2
# Diseño
model12 = keras.Sequential([
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(10, activation="softmax")
])
# Compilacion
model12.compile(optimizer="SGD",
loss ="SparseCategoricalCrossentropy",
metrics =["accuracy"])
# Entrenamiento
model12.fit(train_images, train_labels, epochs=5)
# Guardar accuracy
test_loss, test_acc = model12.evaluate(test_images, test_labels)
accuracy.append(test_acc)

# Modelo 1.3
# Diseño
model13 = keras.Sequential([
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(10, activation="softmax")
])
# Compilacion
model13.compile(optimizer="SGD",
loss ="SparseCategoricalCrossentropy",
metrics =["accuracy"])
# Entrenamiento
model13.fit(train_images, train_labels, epochs=5)
# Guardar accuracy
test_loss, test_acc = model13.evaluate(test_images, test_labels)
accuracy.append(test_acc)

# Modelo 1.4
# Diseño
model14 = keras.Sequential([
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(10, activation="softmax")
])
# Compilacion
model14.compile(optimizer="SGD",
loss ="SparseCategoricalCrossentropy",
metrics =["accuracy"])
# Entrenamiento
model14.fit(train_images, train_labels, epochs=5)
# Guardar accuracy
test_loss, test_acc = model14.evaluate(test_images, test_labels)
accuracy.append(test_acc)

# Modelo 1.5
# Diseño
model15 = keras.Sequential([
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(512, activation="sigmoid"),
    layers.Dense(10, activation="softmax")
])
# Compilacion
model15.compile(optimizer="SGD",
loss ="SparseCategoricalCrossentropy",
metrics =["accuracy"])
# Entrenamiento
model15.fit(train_images, train_labels, epochs=5)
# Guardar accuracy
test_loss, test_acc = model14.evaluate(test_images, test_labels)
accuracy.append(test_acc)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.2089 - loss: 2.2382
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6297 - loss: 1.6011
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7808 - loss: 0.8968
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8345 - loss: 0.6397
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8602 - loss: 0.5234
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8582 - loss: 0.5096
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1100 - loss: 2.3093
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1487 - loss: 2.2786
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.2675 - loss: 2.2093
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.4379 - loss: 1.9152
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6052 - loss: 1.3323
# ...

# %% [markdown]
# Ahora bien esta parte hemos creado los otros 4 modelos (tienen desde 1 capa oculta a 5 capas ocultas) y tambien se han guardado sus metricas de desempeño para comparar, vamos a visualizar estas medidas para poder escribir nuestras observaciones.

# %%
# Crear la figura y establecer el tamaño
plt.figure(figsize=(10, 6))

model_names = [f'Modelo 1.{i}' for i in range(1, 6)]

# Ordenar los modelos y las accuracies de mayor a menor
accuracy_sorted, model_names_sorted = zip(*sorted(zip(accuracy, model_names), reverse=True))

# Graficar el gráfico de barras
bars = plt.bar(model_names_sorted, accuracy_sorted)

# Agregar título y etiquetas a los ejes
plt.title('Accuracy de los modelos por numeros de capas')
plt.xlabel('Modelo')
plt.ylabel('Accuracy')

# Agregar los porcentajes en la parte superior de cada barra
for bar, acc in zip(bars, accuracy_sorted):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{acc:.2%}', ha='center', va='bottom')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Al observar los resultados, podemos concluir que el mejor modelo para continuar trabajando es aquel con *una sola capa oculta sigmoide*. A medida que iteramos la cantidad de capas, notamos un resultado algo contraintuitivo: uno esperaría que al aumentar la cantidad de capas en una red, su rendimiento mejorara. Sin embargo, en este ejercicio observamos lo contrario. La precisión disminuye de forma significativa conforme se agregan más capas ocultas.
#
# Este comportamiento nos lleva a concluir que, en algunos casos, aumentar las capas ocultas no es necesariamente beneficioso, e incluso puede empeorar el rendimiento del modelo. Así, para ciertos problemas, no es necesario añadir más complejidad a la red, ya que podríamos obtener desempeños inferiores. Por lo tanto, para los próximos puntos, seguiremos trabajando con el primer modelo, que contiene una única capa oculta. Este análisis nos demuestra que, a menudo, los ajustes de los modelos se realizan de manera heurística, basados en los resultados observados durante el proceso de experimentación.

# %% [markdown]
# 2. Investigue como implementar los métodos de regularización L2, L1, y Dropout en las redes
# neuronales usando TensorFlow/Keras. En la mejor versión de la red que haya encontrado
# arriba, implemente los métodos de regularización vistos en clase (L2, L1, Dropout). Experimente con diferentes parámetros y describa sus resultados.

# %%
from tensorflow.keras import layers, regularizers

# Inicialización de listas para guardar las precisiones de entrenamiento y prueba
train_acc_L2 = []
test_acc_L2 = []

# Modelo base
test_loss1, test_acc1 = model.evaluate(test_images, test_labels)
train_loss1, train_acc1 = model.evaluate(train_images, train_labels)
train_acc_L2.append(train_acc1)
test_acc_L2.append(test_acc1)

### Regularización L2 Modelo 1
model_l21 = keras.Sequential([
    layers.Dense(512, activation="sigmoid", 
                 kernel_regularizer=regularizers.l2(0.1)),  # Regularización L2
    layers.Dense(10, activation="softmax")
])
# Compilación
model_l21.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_l21.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_l21.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_l21.evaluate(test_images, test_labels)
train_acc_L2.append(train_acc1)
test_acc_L2.append(test_acc1)

### Regularización L2 Modelo 2
model_l22 = keras.Sequential([
    layers.Dense(512, activation="sigmoid", 
                 kernel_regularizer=regularizers.l2(0.01)),  # Regularización L2
    layers.Dense(10, activation="softmax")
])
# Compilación
model_l22.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_l22.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_l22.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_l22.evaluate(test_images, test_labels)
train_acc_L2.append(train_acc1)
test_acc_L2.append(test_acc1)

### Regularización L2 Modelo 3
model_l23 = keras.Sequential([
    layers.Dense(512, activation="sigmoid", 
                 kernel_regularizer=regularizers.l2(0.001)),  # Regularización L2
    layers.Dense(10, activation="softmax")
])
# Compilación
model_l23.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_l23.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_l23.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_l23.evaluate(test_images, test_labels)
train_acc_L2.append(train_acc1)
test_acc_L2.append(test_acc1)

# Crear la figura y una grilla de 1 fila y 2 columnas
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

model_names = [f'Modelo L2.{i}' for i in range(1, 5)]

# Gráfico de precisión de entrenamiento
train_acc_sorted, train_model_names_sorted = zip(*sorted(zip(train_acc_L2, model_names), reverse=True))
bars_train = axes[0].bar(train_model_names_sorted, train_acc_sorted)
axes[0].set_title('Precisión de Entrenamiento (Regularización L2)')
axes[0].set_xlabel('Modelo')
axes[0].set_ylabel('Accuracy')
for bar, acc in zip(bars_train, train_acc_sorted):
    yval = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2, yval, f'{acc:.2%}', ha='center', va='bottom')

# Gráfico de precisión de prueba
test_acc_sorted, test_model_names_sorted = zip(*sorted(zip(test_acc_L2, model_names), reverse=True))
bars_test = axes[1].bar(test_model_names_sorted, test_acc_sorted)
axes[1].set_title('Precisión de Prueba (Regularización L2)')
axes[1].set_xlabel('Modelo')
axes[1].set_ylabel('Accuracy')
for bar, acc in zip(bars_test, test_acc_sorted):
    yval = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2, yval, f'{acc:.2%}', ha='center', va='bottom')

# Ajustar el espaciado entre gráficos
plt.tight_layout()

# Mostrar la gráfica
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8844 - loss: 0.4119
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8953 - loss: 0.3761
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.5142 - loss: 23.4612
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7423 - loss: 1.7399
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7773 - loss: 1.5435
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8053 - loss: 1.4194
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8192 - loss: 1.3325
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8253 - loss: 1.2769
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8130 - loss: 1.3166
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.5589 - loss: 6.9979
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8430 - loss: 3.4094
# Epoch 3/5
# ...

# %% [markdown]
# Aquí tienes una versión mejorada de tu texto:
#
# En este gráfico podemos observar los resultados obtenidos tras entrenar varios modelos utilizando regularización L2 con diferentes valores de λ= 0.1, 0.01, 0.001 (lambda), es decir, distintos grados de penalización. El objetivo de este análisis es mitigar el sobreajuste sin comprometer de manera significativa la precisión del modelo.
#
# Al incrementar el valor de λ, estamos añadiendo una mayor penalización a los pesos de la red. Por ejemplo, con un λ de 0.1, observamos una penalización más fuerte, lo cual impacta negativamente en la precisión del modelo. Esto nos indica que valores de penalización altos pueden reducir el sobreajuste, pero también afectan el rendimiento.
#
# En cambio, cuando usamos un valor de λ más bajo, como 0.001, la penalización es más suave. Esto permite reducir el sobreajuste sin afectar de manera significativa la precisión del modelo. Con base en estos resultados, podemos concluir que un modelo con regularización L2 y un λ de 0.001 sería una opción adecuada para reemplazar el modelo inicial. Aunque revisemos otros metodos de regulazicion como el L1.

# %%
# Inicialización de listas para guardar las precisiones de entrenamiento y prueba
train_acc_L1 = []
test_acc_L1 = []

# Modelo base
test_loss1, test_acc1 = model.evaluate(test_images, test_labels)
train_loss1, train_acc1 = model.evaluate(train_images, train_labels)
train_acc_L1.append(train_acc1)
test_acc_L1.append(test_acc1)

### Regularización L1 Modelo 1
model_l11 = keras.Sequential([
    layers.Dense(512, activation="sigmoid", 
                 kernel_regularizer=regularizers.l1(0.1)),  # Regularización L2
    layers.Dense(10, activation="softmax")
])
# Compilación
model_l11.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_l11.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_l11.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_l11.evaluate(test_images, test_labels)
train_acc_L1.append(train_acc1)
test_acc_L1.append(test_acc1)

### Regularización L1 Modelo 2
model_l12 = keras.Sequential([
    layers.Dense(512, activation="sigmoid", 
                 kernel_regularizer=regularizers.l1(0.01)),  # Regularización L2
    layers.Dense(10, activation="softmax")
])
# Compilación
model_l12.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_l12.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_l12.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_l12.evaluate(test_images, test_labels)
train_acc_L1.append(train_acc1)
test_acc_L1.append(test_acc1)

### Regularización L1 Modelo 3
model_l13 = keras.Sequential([
    layers.Dense(512, activation="sigmoid", 
                 kernel_regularizer=regularizers.l1(0.001)),  # Regularización L2
    layers.Dense(10, activation="softmax")
])
# Compilación
model_l13.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_l13.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_l13.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_l13.evaluate(test_images, test_labels)
train_acc_L1.append(train_acc1)
test_acc_L1.append(test_acc1)

# Crear la figura y una grilla de 1 fila y 2 columnas
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

model_names = [f'Modelo L1.{i}' for i in range(1, 5)]

# Gráfico de precisión de entrenamiento
train_acc_sorted, train_model_names_sorted = zip(*sorted(zip(train_acc_L1, model_names), reverse=True))
bars_train = axes[0].bar(train_model_names_sorted, train_acc_sorted)
axes[0].set_title('Precisión de Entrenamiento (Regularización L1)')
axes[0].set_xlabel('Modelo')
axes[0].set_ylabel('Accuracy')
for bar, acc in zip(bars_train, train_acc_sorted):
    yval = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2, yval, f'{acc:.2%}', ha='center', va='bottom')

# Gráfico de precisión de prueba
test_acc_sorted, test_model_names_sorted = zip(*sorted(zip(test_acc_L1, model_names), reverse=True))
bars_test = axes[1].bar(test_model_names_sorted, test_acc_sorted)
axes[1].set_title('Precisión de Prueba (Regularización L1)')
axes[1].set_xlabel('Modelo')
axes[1].set_ylabel('Accuracy')
for bar, acc in zip(bars_test, test_acc_sorted):
    yval = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2, yval, f'{acc:.2%}', ha='center', va='bottom')

# Ajustar el espaciado entre gráficos
plt.tight_layout()

# Mostrar la gráfica
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8844 - loss: 0.4119
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8953 - loss: 0.3761
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.1033 - loss: 106.8550
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1030 - loss: 22.3825
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.1039 - loss: 22.3830
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.1056 - loss: 22.3823
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.1044 - loss: 22.3829
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0991 - loss: 22.3717
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0921 - loss: 22.3755
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.2845 - loss: 49.5351
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.1077 - loss: 2.5120
# Epoch 3/5
# ...

# %% [markdown]
# Entendiendo cómo funcionan los parámetros de lambda, podemos observar que las penalizaciones grandes afectan significativamente la precisión de los modelos. Esto es particularmente notable cuando aplicamos una penalización elevada, lo cual perjudica el rendimiento de la red. Sin embargo, en el caso de la regularización L1 con un lambda de 0.001, la precisión no se vio tan afectada, aunque, al compararlo con el modelo base, los resultados no superan su buen desempeño.
#
# A continuación, revisemos la regularización por Dropout y sus respectivos resultados, para completar nuestro análisis y determinar que opción más efectiva.

# %%
# Inicialización de listas para guardar las precisiones de entrenamiento y prueba
train_acc_DropOut = []
test_acc_DropOut = []

# Modelo base
test_loss1, test_acc1 = model.evaluate(test_images, test_labels)
train_loss1, train_acc1 = model.evaluate(train_images, train_labels)
train_acc_DropOut.append(train_acc1)
test_acc_DropOut.append(test_acc1)

### Regularización DropOut Modelo 2
model_dropout1 = keras.Sequential([
    layers.Dense(512, activation="sigmoid"),
    layers.Dropout(0.5),  # Dropout con tasa del 50%
    layers.Dense(10, activation="softmax")
])
# Compilación
model_dropout1.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_dropout1.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_dropout1.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_dropout1.evaluate(test_images, test_labels)
train_acc_DropOut.append(train_acc1)
test_acc_DropOut.append(test_acc1)

### Regularización DropOut Modelo 1
model_dropout2 = keras.Sequential([
    layers.Dense(512, activation="sigmoid"),
    layers.Dropout(0.3),  # Dropout con tasa del 50%
    layers.Dense(10, activation="softmax")
])
# Compilación
model_dropout2.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_dropout2.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_dropout2.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_dropout2.evaluate(test_images, test_labels)
train_acc_DropOut.append(train_acc1)
test_acc_DropOut.append(test_acc1)

### Regularización DropOut Modelo 3
model_dropout3 = keras.Sequential([
    layers.Dense(512, activation="sigmoid"),
    layers.Dropout(0.1),  # Dropout con tasa del 50%
    layers.Dense(10, activation="softmax")
])
# Compilación
model_dropout3.compile(optimizer="SGD",
loss="SparseCategoricalCrossentropy",
metrics=["accuracy"])
# Entrenamiento
model_dropout3.fit(train_images, train_labels, epochs=5)
# Guardar precisión de entrenamiento y prueba
train_loss1, train_acc1 = model_dropout3.evaluate(train_images, train_labels)
test_loss1, test_acc1 = model_dropout3.evaluate(test_images, test_labels)
train_acc_DropOut.append(train_acc1)
test_acc_DropOut.append(test_acc1)

# Crear la figura y una grilla de 1 fila y 2 columnas
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

model_names = [f'Modelo DropOut.{i}' for i in range(1, 5)]

# Gráfico de precisión de entrenamiento
train_acc_sorted, train_model_names_sorted = zip(*sorted(zip(train_acc_DropOut, model_names), reverse=True))
bars_train = axes[0].bar(train_model_names_sorted, train_acc_sorted)
axes[0].set_title('Precisión de Entrenamiento (Regularización DropOut)')
axes[0].set_xlabel('Modelo')
axes[0].set_ylabel('Accuracy')
for bar, acc in zip(bars_train, train_acc_sorted):
    yval = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width()/2, yval, f'{acc:.2%}', ha='center', va='bottom')

# Gráfico de precisión de prueba
test_acc_sorted, test_model_names_sorted = zip(*sorted(zip(test_acc_DropOut, model_names), reverse=True))
bars_test = axes[1].bar(test_model_names_sorted, test_acc_sorted)
axes[1].set_title('Precisión de Prueba (Regularización DropOut)')
axes[1].set_xlabel('Modelo')
axes[1].set_ylabel('Accuracy')
for bar, acc in zip(bars_test, test_acc_sorted):
    yval = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2, yval, f'{acc:.2%}', ha='center', va='bottom')

# Ajustar el espaciado entre gráficos
plt.tight_layout()

# Mostrar la gráfica
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8844 - loss: 0.4119
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8953 - loss: 0.3761
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.3306 - loss: 1.9397
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7117 - loss: 0.9342
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7777 - loss: 0.7129
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8115 - loss: 0.6125
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8336 - loss: 0.5456
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8872 - loss: 0.4130
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8752 - loss: 0.4497
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.3924 - loss: 1.8407
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7674 - loss: 0.8180
# Epoch 3/5
# ...

# %% [markdown]
# Observando el método de regularización Dropout, que consiste en "apagar" o desactivar aleatoriamente una fracción de las neuronas en una capa durante el entrenamiento, podemos decir que durante cada paso de entrenamiento un subconjunto diferente de neuronas es ignorado al hacer las actualizaciones de los pesos. Hemos experimentado con varias proporciones de Dropout: 50%, 30% y 10%. Aunque no se observan diferencias notables en la precisión al variar este parámetro, destacamos que la precisión en los datos de prueba no se ve afectada significativamente.
#
# Sin embargo, el modelo base sigue mostrando un mejor desempeño, aunque no por un margen considerable. Tras aplicar los diferentes métodos de regularización, podemos concluir que si buscamos un modelo que mejore el rendimiento en comparación con el modelo base, la mejor opción sería el modelo con regularización L2 y una tasa lambda de 0.001. Este será el modelo que utilizaremos para implementar el paso de Early-Stopping.

# %% [markdown]
# 3. Investigue cómo implementar la técnica de Early-Stopping usando TensorFlow/Keras (como
# un callback). En la mejor versión de la red que haya encontrado en el Punto 2, implemente
# el early-stopping. Experimente con diferentes parámetros y describa sus resultados.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Creación del modelo con regularización L2
model_l2_early1 = keras.Sequential([
    layers.Dense(512, activation="sigmoid", 
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(10, activation="softmax")
])

# Compilación del modelo
model_l2_early1.compile(optimizer="SGD",
                 loss="SparseCategoricalCrossentropy",
                 metrics=["accuracy"])

# Definición del callback de Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)

# Entrenamiento con Early Stopping
history = model_l2_early1.fit(train_images, train_labels, 
                       validation_split=0.2,  # 20% de los datos para validación
                       epochs=50,  # Número máximo de épocas
                       callbacks=[early_stopping])  # Incluir el callback

# Evaluar el modelo en los datos de prueba
test_loss1, test_acc1 = model_l2_early1.evaluate(test_images, test_labels, verbose=2)

# Imprimir los resultados
print(f'\nPérdida en datos de prueba: {test_loss:.4f}')
print(f'Precisión en datos de prueba: {test_acc:.4f}')
# Out:
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5445 - loss: 2.4093 - val_accuracy: 0.8103 - val_loss: 1.4619
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8317 - loss: 1.3898 - val_accuracy: 0.8685 - val_loss: 1.1501
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8611 - loss: 1.1452 - val_accuracy: 0.8870 - val_loss: 1.0226
# Epoch 4/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8779 - loss: 1.0318 - val_accuracy: 0.8928 - val_loss: 0.9515
# Epoch 5/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8853 - loss: 0.9643 - val_accuracy: 0.8959 - val_loss: 0.8988
# Epoch 6/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8890 - loss: 0.9117 - val_accuracy: 0.8982 - val_loss: 0.8551
# Epoch 7/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8925 - loss: 0.8673 - val_accuracy: 0.9024 - val_loss: 0.8189
# Epoch 8/30
# ...

# %% [markdown]
# Podemos observar que el uso de Early Stopping es eficaz para evitar el sobreajuste, ya que permite que el modelo se detenga automáticamente si no presenta mejoras durante el entrenamiento. Esto previene un ajuste excesivo a los datos de entrenamiento y evita que se ejecuten épocas innecesarias, lo que a su vez ahorra tiempo computacional.
#
# En este caso, se le agregaron más épocas al entrenamiento con el objetivo de permitir que la red busque continuamente mejoras. Sin embargo, el modelo se detendrá si, durante 30 épocas, no se identifica ninguna mejora. A pesar de esto, los resultados indican que el mejor desempeño se logró después de aplicar las 30 épocas en la red que hemos regularizado.

# %% [markdown]
# 4. ¿Hubo alguna mejora en el desempeño de su red al comparar los resultados del Taller 1
# con aquellos obtenidos acá? Describa.

# %% [markdown]
# En nuestro Taller 1, nos dimos cuenta que una red que tuvo mejor desempeño que el caso base, una red que tenia una capa 1 con menos neuronas es decir, con 256 neuronas y funcion de activación Relu. Entonces para hacer comparable los resultados y podemos tener una conclusion y una respuesta clara, implementemos esa red del Taller 1 y luego apliquemos los metodos de regularizacion L2, y EarlyStopping para determinar si el desempeño mejora despues de implementar estas nuevas tecnicas.

# %%
# Modelo de 1 capa oculta y 256 neuronas
# Diseño
modelT1 = keras.Sequential([
    layers.Dense(256, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# Compilacion
modelT1.compile(optimizer="SGD",
loss ="SparseCategoricalCrossentropy",
metrics =["accuracy"])

# Entrenamiento
modelT1.fit(train_images, train_labels, epochs=5)

# Guardar accuracy
test_lossT1, test_accT1 = modelT1.evaluate(test_images, test_labels)

# Creación del modelo con regularización L2
model_l2_earlyT1 = keras.Sequential([
    layers.Dense(256, activation="relu", 
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(10, activation="softmax")
])

# Compilación del modelo
model_l2_earlyT1.compile(optimizer="SGD",
                 loss="SparseCategoricalCrossentropy",
                 metrics=["accuracy"])

# Definición del callback de Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Entrenamiento con Early Stopping
history = model_l2_earlyT1.fit(train_images, train_labels, 
                       validation_split=0.2,  # 20% de los datos para validación
                       epochs=30,  # Número máximo de épocas
                       callbacks=[early_stopping])  # Incluir el callback

# Evaluar el modelo en los datos de prueba
test_lossT12, test_accT12 = model_l2_earlyT1.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7457 - loss: 1.0140
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9044 - loss: 0.3460
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9177 - loss: 0.2927
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9272 - loss: 0.2585
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9332 - loss: 0.2360
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9298 - loss: 0.2477
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7233 - loss: 1.4794 - val_accuracy: 0.8991 - val_loss: 0.7516
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8996 - loss: 0.7421 - val_accuracy: 0.9188 - val_loss: 0.6623
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9140 - loss: 0.6621 - val_accuracy: 0.9246 - val_loss: 0.6132
# Epoch 4/30
# ...

# %%
# Imprimir los resultados
print(f'\nPérdida en datos de prueba (Taller1): {test_lossT1:.4f}')
print(f'Precisión en datos de prueba (Taller1): {test_accT1:.4f}')

# Imprimir los resultados
print(f'\nPérdida en datos de prueba (T1 - Regularizacion L2): {test_lossT12:.4f}')
print(f'Precisión en datos de prueba (T1 - Regularizacion L2): {test_accT12:.4f}')
# Out:
# Pérdida en datos de prueba (Taller1): 0.2148
# Precisión en datos de prueba (Taller1): 0.9399
#
# Pérdida en datos de prueba (T1 - Regularizacion L2): 0.2166
# Precisión en datos de prueba (T1 - Regularizacion L2): 0.9702

# %% [markdown]
# Al observar los resultados de estos modelos comparables, podemos notar que las nuevas técnicas que hemos aprendido evidencian una mejora en el desempeño de las redes. Estas herramientas son valiosas para ayudarnos a encontrar el mejor modelo posible. En este caso, el uso de Early Stopping y la regularización L2 han sido fundamentales, Ya que en este caso se paso de tener una precision del 93.99% se llego a una precision del 97.02%.
#
# Además, en diferentes tipos de problemas, la regularización L1 o el aumento en la cantidad de capas ocultas pueden ser útiles. El Early Stopping, por su parte, nos permite identificar la época más adecuada para detener el entrenamiento, evitando así gastos computacionales innecesarios.
